# %%
import openai
import pandas as pd
import random

# %%
# api_key를 입력하세요.
openai.api_key  = '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'

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.1, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

# %%
# 데이터 불러오기
df = pd.read_csv("./data/df_cluster.csv")
df.head()
# Out:
#                                                  url  \
# 0  https://n.news.naver.com/mnews/article/001/001...
# 1  https://n.news.naver.com/mnews/article/008/000...
# 2  https://n.news.naver.com/mnews/article/016/000...
# 3  https://n.news.naver.com/mnews/article/031/000...
# 4  https://n.news.naver.com/mnews/article/001/001...
#
#                                  title        date  \
# 0    이스라엘, 가자 '구호트럭 참사' 원인은 "공격 아닌 압사"  2024-03-03
# 1  與윤재옥 "김영주 부의장 입당, 우리 당 시야 넓히는 데 도움"  2024-03-03
# 2         빅5 대형병원도 응급실 '빨간불'…전임의 이탈 촉각  2024-03-03
# 3    대통령실 "의대 증원 2천명 변화 없어…비수도권 집중 배치"  2024-03-03
# 4    먹과 두드림으로 기록하는 역사…국보 정림사지 석탑 탁본 뜬다  2024-03-03
#
#                                              content  \
# 0   "압사 방지 위한 경고 사격 후 약탈자들이 위협해 대응 사격" 가자시티 구호 트럭...
# 1   [the300] 현역 교체 비율 낮다는 지적에 "국민들 눈높이에서 생각해보고 개선...
# 2   상급종합병원, 환자 더 줄일 듯정부 "오늘까지 돌아오면 선처"거리 나온 의사들 "...
# 3   현장 복귀 안한 전공의 "법과 원칙에 따른 절차 불가피"성태윤 대통령실 정책실장은...
# 4   문화재위원회, 총 4건 금석문 탁본 허가…고대사·서예사 연구에 도움 국보 '부여 ...
#
#                                                nouns  cluster_dbscan  cluster
# 0  ['압사', '방지', '위', '경고', '사격', '후', '약탈', '위협',...               0      NaN
# 1  ['현역', '교체', '비율', '지적', '국민', '눈높이', '생각', '개...               1     10.0
# 2  ['상급', '종합병원', '환자', '더', '듯', '정부', '오늘', '선처...               2      1.0
# 3  ['현장', '복귀', '안', '전공', '법', '원칙', '절차', '불가피'...               3      1.0
# 4  ['문화재', '위원회', '총', '건', '금석문', '탁본', '허가', '대...               4     11.0

# %%
score = []
keyword = []
cluster = []

for i in list(set(df['cluster'])):
    if (i == -1) or (pd.isna(i)) or(i == 11): # 내부 거리 가장 컸던 클러스터 추가
        continue
    li_title = []
    titles_list = list(df[df['cluster'] == i]['title'])
    random.shuffle(titles_list)
    for title in titles_list:
        li_title.append(title)
        if (len(li_title) > 90):
            break
    score.append(len(df[df['cluster'] == i]))
    cluster.append(i)
    story = li_title.copy()
    prompt = f"""
    Determine main one keyword that are being discussed in the following text.
    
    Please present keyword by short word phrases.
    
    Please present the answer only in Korean.
    
    Text sample: '''{story}'''
    """
    response = get_completion(prompt)
    keyword.append(response)
    print(f"cluster : {i} number : {len(li_title)} \n ---------------------- \n {response}")
# Out:
# cluster : 1.0 number : 91
#  ----------------------
#  전공의
# cluster : 2.0 number : 91
#  ----------------------
#  '쌍특검법'
# cluster : 4.0 number : 91
#  ----------------------
#  지역주택조합
# cluster : 5.0 number : 80
#  ----------------------
#  성별 감별
# cluster : 6.0 number : 91
#  ----------------------
#  연기금
# cluster : 7.0 number : 80
#  ----------------------
#  마약범
# cluster : 8.0 number : 60
#  ----------------------
#  수은법
# cluster : 9.0 number : 91
#  ----------------------
#  '의대 증원'
# cluster : 10.0 number : 91
#  ----------------------
#  전세사기
# cluster : 12.0 number : 91
#  ----------------------
#  선거
# cluster : 13.0 number : 91
#  ----------------------
#  의협
# cluster : 14.0 number : 56
#  ----------------------
#  이성윤
# cluster : 15.0 number : 91
#  ----------------------
#  선거구 획정
# cluster : 16.0 number : 91
#  ----------------------
#  중국
# cluster : 17.0 number : 91
#  ----------------------
#  선거구 획정안
# cluster : 18.0 number : 39
#  ----------------------
#  러시아
# cluster : 19.0 number : 31
#  ----------------------
#  부탄가스
# cluster : 20.0 number : 64
#  ----------------------
#  '쌍특검법'
# cluster : 21.0 number : 91
#  ----------------------
#  음주운전
# cluster : 22.0 number : 54
#  ----------------------
#  실거주 의무
# cluster : 23.0 number : 91
#  ----------------------
#  주사제
# cluster : 24.0 number : 68
#  ----------------------
#  중대재해법
# cluster : 25.0 number : 56
#  ----------------------
#  전공의
# cluster : 26.0 number : 58
#  ----------------------
#  임대차 계약갱신청구권
# cluster : 27.0 number : 91
#  ----------------------
#  성범죄
# cluster : 28.0 number : 42
#  ----------------------
#  전공의
# cluster : 0.0 number : 47
#  ----------------------
#  '의료사고 특례법'
# cluster : 3.0 number : 57
#  ----------------------
#  '돈봉투'

# %%
# 키워드 정리 : 키워드 여러 개 있는 것 삭제 -> 이 과정 필요없도록 만들어야 함
keyword_df = pd.DataFrame({"keyword" : keyword, "cluster" : cluster, "score" : score})
keyword_df = keyword_df.sort_values("score", ascending = False).reset_index(drop = True)

for i in range(len(keyword_df)):
    if "," in keyword_df.loc[i, "keyword"]:
        keyword_df.drop(i, axis = 0, inplace = True)

keyword_df = keyword_df.reset_index(drop = True)

# %%
li_keyword = []
for i in range(len(df)):
    k = len(li_keyword)
    for j in range(len(keyword_df)):
        if df.loc[i, 'cluster'] == keyword_df.loc[j, 'cluster']:
            li_keyword.append(keyword_df.loc[j, 'keyword'])
    k_new = len(li_keyword)
    if k == k_new:
        li_keyword.append('notaissue')
            
df['keyword'] = li_keyword

# %%
keyword_df.to_csv("./data/keyword_rank.csv", index = False)
pd.read_csv("./data/keyword_rank.csv")
# Out:
#         keyword  cluster  score
# 0        지역주택조합      4.0    393
# 1           전공의      1.0    353
# 2           연기금      6.0    241
# 3            의협     13.0    225
# 4            선거     12.0    206
# 5          음주운전     21.0    193
# 6           성범죄     27.0    180
# 7       '의대 증원'      9.0    146
# 8        '쌍특검법'      2.0    144
# 9           주사제     23.0    112
# 10       선거구 획정     15.0    104
# 11         전세사기     10.0    102
# 12           중국     16.0     95
# 13      선거구 획정안     17.0     91
# 14          마약범      7.0     80
# 15        성별 감별      5.0     80
# 16        중대재해법     24.0     68
# 17       '쌍특검법'     20.0     64
# 18          수은법      8.0     60
# 19  임대차 계약갱신청구권     26.0     58
# 20        '돈봉투'      3.0     57
# 21          이성윤     14.0     56
# 22          전공의     25.0     56
# 23       실거주 의무     22.0     54
# 24   '의료사고 특례법'      0.0     47
# 25          전공의     28.0     42
# 26          러시아     18.0     39
# 27         부탄가스     19.0     31
